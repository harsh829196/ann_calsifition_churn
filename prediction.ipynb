# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model
import pickle   
import pandas as pd
import numpy as np

# %%
# 
model = load_model('churn_model.h5')
with open('preprocessor_geography.pkl', 'rb') as f:
    label_encoder_geo = pickle.load(f)

with open('preprocessor_gender.pkl', 'rb') as f:
    label_encoder_gen = pickle.load(f)  
with open('preprocessor.pkl', 'rb') as f:
    scaler = pickle.load(f)
# Out:
# 2026-05-22 22:29:30.079163: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-05-22 22:29:30.079307: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2026-05-22 22:29:30.079935: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2026-05-22 22:29:30.080820: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-05-22 22:29:30.081979: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 input_data= pd.DataFrame([input_data])
#
# File ~/Downloads/myannclasificationattempt/annclassy/lib/python3.11/site-packages/pandas/core/frame.py:852, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     845         mgr = arrays_to_mgr(
#     846             arrays,
#     847             columns,
#     848             index,
#     849             dtype=dtype,
#     850         )
#     851     else:
# --> 852         mgr = ndarray_to_mgr(
#     853             data,
#     854             index,
#     855             columns,
#     856             dtype=dtype,
#     857             copy=copy,
#     858         )
#     859 else:
#     860     mgr = dict_to_mgr(
#     861         {},
#     862         index,
#     863         columns if columns is not None else default_index(0),
# ...

# %%
# Example input data for prediction
input_data = {
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 3,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000
}

# %%
input_data= pd.DataFrame([input_data])

# %%
geo_encoded = label_encoder_geo.transform(input_data[['Geography']])
geo_encoded = pd.DataFrame(geo_encoded, columns=label_encoder_geo.get_feature_names_out(['Geography']))
geo_encoded
geo_encoded= pd.DataFrame(geo_encoded, columns=label_encoder_geo.get_feature_names_out(['Geography']))
geo_encoded
# Out:
# /Users/harshvardhansingh/Downloads/myannclasificationattempt/annclassy/lib/python3.11/site-packages/sklearn/utils/validation.py:2684: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
#                                     Geography_France
# 0  <Compressed Sparse Row sparse matrix of dtype ...

# %%
input_data = pd.concat([input_data, geo_encoded], axis=1)
input_data
input_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 input_data = pd.concat([pd.DataFrame([input_data]), geo_encoded], axis=1)
#       2 input_data
#
# File ~/Downloads/myannclasificationattempt/annclassy/lib/python3.11/site-packages/pandas/core/frame.py:852, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     845         mgr = arrays_to_mgr(
#     846             arrays,
#     847             columns,
#     848             index,
#     849             dtype=dtype,
#     850         )
#     851     else:
# --> 852         mgr = ndarray_to_mgr(
#     853             data,
#     854             index,
#     855             columns,
#     856             dtype=dtype,
#     857             copy=copy,
#     858         )
#     859 else:
#     860     mgr = dict_to_mgr(
#     861         {},
#     862         index,
# ...
